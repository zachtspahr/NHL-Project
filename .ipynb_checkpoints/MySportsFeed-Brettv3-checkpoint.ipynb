# %%
from ohmysportsfeedspy import MySportsFeeds
import simplejson as json
import pandas as pd

# %%
msf = MySportsFeeds(version="1.2")
msf.authenticate("ff3a9d40-4a07-42fb-91f6-00446c","6dRSvQq4F3evp!C")

# %%
#Available stats for each game by a team
#Testing connection
#output = msf.msf_get_data(league='nhl',season='2018-2019-regular',feed='overall_team_standings',team='nyi', format='json')
#statslist = output["overallteamstandings"]["teamstandingsentry"][0]["stats"]["stats"]
#print(json.dumps(output["overallteamstandings"]["teamstandingsentry"][0]["stats"]["stats"]["BlockedShots"]["#text"], indent=4, sort_keys=True))
output = msf.msf_get_data(league='nhl',season="2015-2016-regular",feed='team_gamelogs',team="nyi", format='json')
statslist = output["teamgamelogs"]["gamelogs"][0]['stats']
statslist
# Out:
# {'Wins': {'@category': 'Standings', '@abbreviation': 'W', '#text': '0'},
#  'Losses': {'@category': 'Standings', '@abbreviation': 'L', '#text': '0'},
#  'OvertimeWins': {'@category': 'Standings',
#   '@abbreviation': 'OTW',
#   '#text': '0'},
#  'OvertimeLosses': {'@category': 'Standings',
#   '@abbreviation': 'OTL',
#   '#text': '1'},
#  'ShootoutWins': {'@category': 'Standings',
#   '@abbreviation': 'SOW',
#   '#text': '0'},
#  'ShootoutLosses': {'@category': 'Standings',
#   '@abbreviation': 'SOL',
#   '#text': '0'},
#  'Rows': {'@category': 'Standings', '@abbreviation': 'ROW', '#text': '0'},
#  'GoalsFor': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GF',
#   '#text': '2'},
#  'GoalsAgainst': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GA',
#   '#text': '3'},
#  'FaceoffWins': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O W',
#   '#text': '40'},
#  'FaceoffLosses': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O L',
#   '#text': '27'},
#  'FaceoffPercent': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O %',
#   '#text': '59.7'},
#  'Powerplays': {'@category': 'Powerplay', '@abbreviation': 'PP', '#text': '2'},
#  'PowerplayGoals': {'@category': 'Powerplay',
#   '@abbreviation': 'PPG',
#   '#text': '0'},
#  'PowerplayPercent': {'@category': 'Powerplay',
#   '@abbreviation': 'PP%',
#   '#text': '0.0'},
#  'PenaltyKills': {'@category': 'Powerplay',
#   '@abbreviation': 'PK',
#   '#text': '3'},
#  'PenaltyKillGoalsAllowed': {'@category': 'Powerplay',
#   '@abbreviation': 'PKGA',
#   '#text': '1'},
#  'PenaltyKillPercent': {'@category': 'Powerplay',
#   '@abbreviation': 'PK%',
#   '#text': '66.7'},
#  'ShorthandedGoalsFor': {'@category': 'Powerplay',
#   '@abbreviation': 'SHGF',
#   '#text': '0'},
#  'ShorthandedGoalsAgainst': {'@category': 'Powerplay',
#   '@abbreviation': 'SHGA',
#   '#text': '1'},
#  'Points': {'@category': 'Standings', '@abbreviation': 'Pts', '#text': '1'},
#  'Shots': {'@category': 'Miscellaneous', '@abbreviation': 'Sh', '#text': '36'},
#  'Penalties': {'@category': 'Miscellaneous',
#   '@abbreviation': 'Pn',
#   '#text': '3'},
#  'PenaltyMinutes': {'@category': 'Miscellaneous',
#   '@abbreviation': 'PIM',
#   '#text': '6'},
#  'Hits': {'@category': 'Miscellaneous', '@abbreviation': 'Ht', '#text': '42'}}

# %%
## Building a loop to go through each season,each team, each game
## What is missing is the full list of team IDS, and including a Try and Except.
## we can use this lopp to build the dataframe of the stats we need.
##This is a limited test over three seasons

#Defining Lists
ListSeason=[]
ListTeam=[]
ListTeamName=[]
ListblockedShots=[]
ListgoalsAgainst=[]
ListpenaltyKillPercent=[]
ListPenaltyMinutes=[]
ListpenaltyKillgoals=[]
Listpenalties = []
ListWin=[]
ListfaceoffPercent=[]
ListfaceoffWins=[]
ListfaceoffLosses=[]
Listshots = []
Listhits = []

#Defining seasons & teams
TargetSeasons=["2016-2017-regular","2015-2016-regular"]
teams=['SJS','STL','CBJ','NSH','TOR','WPJ','MTL','DAL','COL','FLO','ARI','CHI','MIN','PHI','ANA','EDM','VAN','NYR','BUF','DET','NJD','LAK','OTT','TBL','CGY','BOS','WSH','NYI','PIT','CAR']

#full set of teams including Vegas 
    #teams=['SJS','VGK','STL','CBJ','NSH','TOR','WPJ','MTL','DAL','COL','FLO','ARI','CHI','MIN','PHI','ANA','EDM','VAN','NYR','BUF','DET','NJD','LAK','OTT','TBL','CGY','BOS','WSH','NYI','PIT','CAR']

#Creating loops to fill the lists
try:
    for season in TargetSeasons:
        for team in teams:
            for game in range (0,83):
                try:
                    TeamGameLogs = msf.msf_get_data(league='nhl',season=season,feed='team_gamelogs',team=team, format='json') 
                    teamname = TeamGameLogs["teamgamelogs"]["gamelogs"][game]["team"]["Abbreviation"]
                    #BlockedShots=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["BlockedShots"]["#text"]
                    win=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["Wins"]["#text"]
                    goalsAgainst=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["GoalsAgainst"]["#text"]
                    PenaltyKillPercent=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["PenaltyKillPercent"]["#text"]
                    penalties=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["Penalties"]["#text"]
                    penaltyminutes=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["PenaltyMinutes"]["#text"]
                    penaltykillgoals=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["PenaltyKillGoalsAllowed"]["#text"]
                    FaceoffPerc=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["FaceoffPercent"]["#text"]
                    Faceoffwin=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["FaceoffWins"]["#text"]
                    Faceoffloss=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["FaceoffLosses"]["#text"]
                    shots=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["Shots"]["#text"]
                    hits=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["Hits"]["#text"]
                    print("workinnnngggg")
                    
                except:
                    continue

                ## Adding values to list
                ListSeason.append(season)
                ListTeam.append(team)
                ListTeamName.append(teamname)
                #ListblockedShots.append(BlockedShots)
                ListWin.append(win)
                ListgoalsAgainst.append(goalsAgainst)
                ListpenaltyKillPercent.append(PenaltyKillPercent)
                Listpenalties.append(penalties)                
                ListPenaltyMinutes.append(penaltyminutes)
                ListpenaltyKillgoals.append(penaltykillgoals)
                ListfaceoffPercent.append(FaceoffPerc)
                ListfaceoffWins.append(Faceoffwin)
                ListfaceoffLosses.append(Faceoffloss)
                Listshots.append(shots)
                Listhits.append(hits)
except:
    print("Error Found")
    
    
print ("Completed")
# Out:
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg
# workinnnngggg

# %%
#zipping the lists and creating a dataframe

#This list includes blocked shots
    #ZipList=list(zip(ListSeason, ListTeam, ListTeamName, ListblockedShots,ListgoalsAgainst,ListpenaltyKillPercent,Listpenalties,ListPenaltyMinutes,ListpenaltyKillgoals,ListWin,ListfaceoffPercent,ListfaceoffWins,ListfaceoffLosses,Listshots,Listhits))

ZipList=list(zip(ListSeason, ListTeam, ListTeamName, ListgoalsAgainst,ListpenaltyKillPercent,Listpenalties,ListPenaltyMinutes,ListpenaltyKillgoals,ListWin,ListfaceoffPercent,ListfaceoffWins,ListfaceoffLosses,Listshots,Listhits))
Gamesdf = pd.DataFrame(ZipList, columns = ["Season",
                                           "Team",
                                           "Team Name",
                                           #"Blocked Shots",
                                           "Goals Against",
                                           "Penalty Kill Percent",
                                           "Penalties",
                                           "Penalty Minutes",
                                           "Penalty Kill Goals Allowed",
                                           "Win",
                                           "Faceoff Percent",
                                           "Faceoff Wins",
                                           "Faceoff Losses",
                                           "Shots",
                                           "Hits"])

Gamesdf["Win"]=Gamesdf["Win"].astype('int32')
#Gamesdf["Blocked Shots"]=Gamesdf["Blocked Shots"].astype('int32')
Gamesdf["Goals Against"]=Gamesdf["Goals Against"].astype('int32')
Gamesdf["Penalty Kill Percent"]=Gamesdf["Penalty Kill Percent"].astype('float')
Gamesdf["Penalties"]=Gamesdf["Penalties"].astype('int32')
Gamesdf["Penalty Minutes"]=Gamesdf["Penalty Minutes"].astype('int32')
Gamesdf["Penalty Kill Goals Allowed"]=Gamesdf["Penalty Kill Goals Allowed"].astype('int32')
Gamesdf["Faceoff Percent"]=Gamesdf["Faceoff Percent"].astype('float')
Gamesdf["Faceoff Wins"]=Gamesdf["Faceoff Wins"].astype('int32')
Gamesdf["Faceoff Losses"]=Gamesdf["Faceoff Losses"].astype('int32')
Gamesdf["Shots"]=Gamesdf["Shots"].astype('int32')
Gamesdf["Hits"]=Gamesdf["Hits"].astype('int32')
export_csv = Gamesdf.to_csv ('2015-2017_gamelog.csv', index = None, header=True)
Gamesdf.head(5)
# Out:
#               Season Team Team Name  Goals Against  Penalty Kill Percent  \
# 0  2016-2017-regular  SJS       SJS              1                   0.0
# 1  2016-2017-regular  SJS       SJS              2                  50.0
# 2  2016-2017-regular  SJS       SJS              7                  66.7
# 3  2016-2017-regular  SJS       SJS              2                 100.0
# 4  2016-2017-regular  SJS       SJS              3                  80.0
#
#    Penalties  Penalty Minutes  Penalty Kill Goals Allowed  Win  \
# 0          2                4                           1    1
# 1          2                4                           1    1
# 2          4                8                           1    0
# 3          2                4                           0    1
# 4          6               20                           1    0
#
#    Faceoff Percent  Faceoff Wins  Faceoff Losses  Shots  Hits
# 0             50.0            28              28     31    24
# 1             41.7            25              35     38    11
# 2             42.6            29              39     31    17
# 3             39.7            25              38     27    13
# 4             47.5            28              31     34    14

# %%
#IGNORE THIS CELL. STILL WORKING ON IT.

# File to Load (Remember to Change These)
file_to_load = "2015-2019_gamelog.csv"

# Read Purchasing File and store into Pandas data frame
gamelog_15_19 = pd.read_csv(file_to_load)
gamelog_15_19.head()
# Out:
#               Season Team Team Name  Blocked Shots  Goals Against  \
# 0  2017-2018-regular  SJS       SJS           17.0              5
# 1  2017-2018-regular  SJS       SJS           14.0              4
# 2  2017-2018-regular  SJS       SJS           15.0              2
# 3  2017-2018-regular  SJS       SJS           20.0              3
# 4  2017-2018-regular  SJS       SJS           20.0              2
#
#    Penalty Kill Percent  Penalties  Penalty Minutes  \
# 0                  40.0          5               10
# 1                 100.0          6               12
# 2                 100.0          3                6
# 3                 100.0          4                8
# 4                  83.3          6               12
#
#    Penalty Kill Goals Allowed  Win  Faceoff Percent  Faceoff Wins  \
# 0                           3    0             48.3            28
# 1                           0    0             50.7            35
# 2                           0    1             52.9            36
# 3                           0    0             65.4            34
# 4                           1    1             52.7            29
#
#    Faceoff Losses  Shots  Hits
# 0              30     35    14
# 1              34     25    29
# 2              32     26    23
# 3              18     41    16
# 4              26     35    20

# %%
#Grouping by

teamstats=Gamesdf.groupby("Team Name").agg({
#    'Blocked Shots':sum,
    'Goals Against':sum,
    'Penalty Kill Percent':"mean",
    'Penalties':sum,   
    'Penalty Minutes':sum,
    'Penalty Kill Goals Allowed':sum,
    'Faceoff Percent':"mean",
    'Faceoff Wins':sum,
    'Faceoff Losses':sum,
    'Shots':sum,   
    'Hits':sum,
    })
teamstats["PK Goals Allows/Min"] = teamstats["Penalty Kill Goals Allowed"] / teamstats["Penalty Minutes"]
teamstats["FO %"] = teamstats["Faceoff Wins"] / (teamstats["Faceoff Wins"] + teamstats["Faceoff Losses"])*100
teamstats=teamstats.drop(['Penalty Kill Percent','Penalty Minutes','Penalty Kill Goals Allowed','Faceoff Percent','Faceoff Wins','Faceoff Losses'], axis=1)
export_csv = teamstats.to_csv ('2015-2017_teamstats.csv', header=True)
teamstats
# Out:
#            Goals Against  Penalties  Shots  Hits  PK Goals Allows/Min  \
# Team Name
# ANA                  385        772   4909  4380             0.040589
# ARI                  502        737   4543  3913             0.069717
# BOS                  437        721   5342  3940             0.047725
# BUF                  446        590   4908  3788             0.060748
# CAR                  451        482   4943  3161             0.061303
# CBJ                  441        691   4926  3799             0.053395
# CGY                  476        682   4786  3250             0.062212
# CHI                  419        531   5004  2567             0.077307
# COL                  516        650   4644  3535             0.073907
# DAL                  488        634   5130  3108             0.071288
# DET                  463        765   4764  3295             0.051241
# EDM                  449        662   4933  3890             0.047544
# FLO                  431        701   4999  3574             0.054458
# LAK                  393        664   5176  4816             0.055760
# MIN                  410        534   4900  2690             0.067213
# MTL                  431        634   4962  3797             0.060350
# NJD                  443        790   4281  3501             0.034761
# NSH                  433        658   5064  3546             0.054086
# NYI                  449        628   4890  4438             0.044304
# NYR                  431        573   4764  3878             0.075559
# OTT                  451        699   4786  4374             0.063392
# PHI                  441        700   5123  4259             0.055403
# PIT                  428        643   5469  4007             0.064880
# SJS                  407        563   4939  3225             0.063135
# STL                  413        684   4803  3624             0.050404
# TBL                  422        701   4850  3524             0.052910
# TOR                  474        672   5129  4056             0.059720
# VAN                  480        593   4583  3004             0.067164
# WPJ                  491        728   4873  4008             0.069807
# WSH                  368        663   5002  3721             0.054269
#
#                 FO %
# Team Name
# ANA        53.333333
# ARI        51.359936
# BOS        51.816575
# BUF        49.491973
# CAR        53.389374
# CBJ        48.817872
# CGY        48.761080
# CHI        48.370192
# COL        51.719864
# DAL        50.053476
# DET        51.192946
# EDM        47.928275
# FLO        49.016100
# LAK        50.637230
# MIN        52.235772
# MTL        50.333137
# NJD        47.869023
# NSH        50.125691
# NYI        48.871380
# NYR        48.776662
# OTT        50.771388
# PHI        51.634919
# PIT        48.871452
# SJS        49.435292
# STL        50.779352
# TBL        48.547463
# TOR        50.244332
# VAN        48.315063
# WPJ        47.623956
# WSH        49.691326

# %%
#Grouping by win/loss to compare stats

WinLoss=Gamesdf.groupby("Win").mean()
WinLoss["PK Goals Allows/Min"] = WinLoss["Penalty Kill Goals Allowed"] / WinLoss["Penalty Minutes"]
WinLoss["FO %"] = WinLoss["Faceoff Wins"] / (WinLoss["Faceoff Wins"] + WinLoss["Faceoff Losses"])*100
WinLoss=WinLoss.drop(['Penalty Kill Percent','Penalty Minutes','Penalty Kill Goals Allowed','Faceoff Percent','Faceoff Wins','Faceoff Losses'], axis=1)
export_csv = WinLoss.to_csv ('2015-2017_WinLoss.csv', header=True)
WinLoss
# Out:
#      Goals Against  Penalties      Shots       Hits  PK Goals Allows/Min  \
# Win
# 0         3.669919   4.055691  30.045935  23.100813             0.070372
# 1         1.723984   3.970732  29.882927  21.886179             0.043315
#
#           FO %
# Win
# 0    50.163173
# 1    49.836827

# %%
#available feeds

['cumulative_player_stats',
 'full_game_schedule',
 'daily_game_schedule',
 'daily_player_stats',
 'game_boxscore',
 'scoreboard',
 'game_playbyplay', 
 'player_gamelogs',
 'team_gamelogs',
 'roster_players',
 'game_startinglineup',
 'active_players',
 'overall_team_standings',
 'conference_team_standings',
 'division_team_standings',
 'playoff_team_standings',
 'player_injuries',
 'daily_dfs',
 'current_season',
 'latest_updates']
